# %%
import mediapipe as mp
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
image_color = cv2.imread('./data/train_images/C/C12.jpg')

# %%
plt.imshow(image_color, cmap='gray')
plt.show()

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)

# %%
sharpening_kernel = np.array([
    [0, -1, 0],
    [-1, 6, -1],
    [0, -1, 0]
])

sharpened_image = cv2.filter2D(image_gray, -1, sharpening_kernel)

# %%
plt.imshow(sharpened_image, cmap='gray')
plt.show()

# %%
plt.imshow(image_gray, cmap='gray')
plt.show()

# %%
image_gray/255
# Out:
# array([[0.12941176, 0.1254902 , 0.10980392, ..., 0.12156863, 0.10980392,
#         0.11372549],
#        [0.10980392, 0.10588235, 0.1254902 , ..., 0.11372549, 0.09411765,
#         0.11764706],
#        [0.12156863, 0.12941176, 0.21568627, ..., 0.71764706, 0.71764706,
#         0.12156863],
#        ...,
#        [0.11764706, 0.10196078, 0.57647059, ..., 0.58039216, 0.58431373,
#         0.10980392],
#        [0.11372549, 0.11372549, 0.57647059, ..., 0.58039216, 0.56470588,
#         0.11372549],
#        [0.11764706, 0.11372549, 0.10588235, ..., 0.11372549, 0.10588235,
#         0.11764706]])

# %%
image_resized = cv2.resize(image_gray, (50, 50), interpolation=cv2.INTER_AREA)

# %%
plt.imshow(image_resized, cmap='gray')
plt.show()

# %%
harpening_kernel = np.array([
    [0, -1, 0],
    [-1, 6, -1],
    [0, -1, 0]
])

sharpened_image = cv2.filter2D(image_resized, -1, sharpening_kernel)

# %%
plt.imshow(sharpened_image, cmap='gray')
plt.show()

# %%
sharpened_image.shape
# Out:
# (50, 50)

# %%
test_img = cv2.imread('./data/transformed/C/C12.jpg',0)

test_img.shape
# Out:
# (50, 50, 3)
